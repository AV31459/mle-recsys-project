# %%
import os

from dotenv import load_dotenv

from utils.s3 import print_bucket_contents

# %%
print_bucket_contents(print_objects=True)
# Out:
# Contents of bucket 's3-student-mle-20240325-173e6ff593':
# ----------------------------------------
# File Name                                                Size (MB)
# ----------------------------------------
# 2/002a23216f15420cb68800d0bb6b4146/artifacts/models/MLmodel            0.00 MB
# 2/002a23216f15420cb68800d0bb6b4146/artifacts/models/conda.yaml            0.00 MB
# 2/002a23216f15420cb68800d0bb6b4146/artifacts/models/input_example.json            0.00 MB
# 2/002a23216f15420cb68800d0bb6b4146/artifacts/models/model.pkl            1.05 MB
# 2/002a23216f15420cb68800d0bb6b4146/artifacts/models/python_env.yaml            0.00 MB
# 2/002a23216f15420cb68800d0bb6b4146/artifacts/models/requirements.txt            0.00 MB
# 2/0bf6b5bc0a2c4b1ab919d81728219cb6/artifacts/models/MLmodel            0.00 MB
# 2/0bf6b5bc0a2c4b1ab919d81728219cb6/artifacts/models/conda.yaml            0.00 MB
# 2/0bf6b5bc0a2c4b1ab919d81728219cb6/artifacts/models/model.pkl            3.30 MB
# ...
